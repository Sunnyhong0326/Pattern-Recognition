# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import *

# %%
np.random.seed(0)  

train_x, train_y, val_x, val_y = generate_poly_data(100)
plot_regression_result(train_x, train_y)
plot_error(train_x, train_y, val_x, val_y)

# %%
np.random.seed(1)  
train_x, train_y, val_x, val_y = generate_poly_data(100)
plot_regression_result(train_x, train_y)
plot_error(train_x, train_y, val_x, val_y)

# %%
np.random.seed(2)  
train_x, train_y, val_x, val_y = generate_poly_data(100)
plot_regression_result(train_x, train_y)
plot_error(train_x, train_y, val_x, val_y)

# %%
np.random.seed(3)  
train_x, train_y, val_x, val_y = generate_poly_data(100)
plot_regression_result(train_x, train_y)
plot_error(train_x, train_y, val_x, val_y)

# %%
np.random.seed(4)  
train_x, train_y, val_x, val_y = generate_poly_data(100)
plot_regression_result(train_x, train_y)
plot_error(train_x, train_y, val_x, val_y)

# %%
np.random.seed(5)  
train_x, train_y, val_x, val_y = generate_poly_data(100)
plot_regression_result(train_x, train_y)
plot_error(train_x, train_y, val_x, val_y)

# %%
np.random.seed(6)  
train_x, train_y, val_x, val_y = generate_poly_data(100)
plot_regression_result(train_x, train_y)
plot_error(train_x, train_y, val_x, val_y)

# %%
np.random.seed(7)  
train_x, train_y, val_x, val_y = generate_poly_data(100)
plot_regression_result(train_x, train_y)
plot_error(train_x, train_y, val_x, val_y)

# %%
np.random.seed(8)  
train_x, train_y, val_x, val_y = generate_poly_data(100)
plot_regression_result(train_x, train_y)
plot_error(train_x, train_y, val_x, val_y)

# %%
np.random.seed(9)  
train_x, train_y, val_x, val_y = generate_poly_data(100)
plot_regression_result(train_x, train_y)
plot_error(train_x, train_y, val_x, val_y)
